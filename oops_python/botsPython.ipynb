# %%
import requests
from datetime import datetime
r = requests.get("https://www.nepsealpha.com/api/smx9841/investment_calander")
data = r.json()
data
# Out:
# {'dividents': [{'id': 12879,
#    'symbol': 'SPIL',
#    'company_name': 'Siddhartha Premier Insurance Limited',
#    'bonus_dividend': '0',
#    'cash_dividend': '11',
#    'book_closure_date': None,
#    'fiscal_year': '2079/2080',
#    'created_at': '2024-02-05T09:55:56.000000Z',
#    'updated_at': '2024-02-05T09:55:56.000000Z',
#    'avg_3yr_dividend': None,
#    'dividend_growth_rate': None,
#    'formatted_fiscal_year': '2079/2080',
#    'status': '<span style="text-align: center" class="no-line-break ">--</span>'},
#   {'id': 12878,
#    'symbol': 'SWMF',
#    'company_name': 'Suryodaya Womi Laghubitta Bittiya Sanstha Limited',
#    'bonus_dividend': '14.077',
#    'cash_dividend': None,
#    'book_closure_date': None,
#    'fiscal_year': '2079/2080',
#    'created_at': '2024-02-04T07:04:58.000000Z',
#    'updated_at': '2024-02-04T07:04:58.000000Z',
#    'avg_3yr_dividend': None,
#    'dividend_growth_rate': None,
#    'formatted_fiscal_year': '2079/2080',
# ...

# %%
date = datetime.now()
date
# Out:
# datetime.datetime(2024, 2, 6, 7, 21, 33, 395037)

# %%
today_date = date.strftime("%Y-%m-%d") 
data['ipo']
# Out:
# [{'id': 3140,
#   'symbol': 'SARBOTTAM(Nepalese Working Abroad)',
#   'company_name': 'Sarbottam Cement Limited',
#   'units': '267000',
#   'opening_date': '2024-01-10',
#   'closing_date': '2024-01-24',
#   'issue_manager': 'Global IME Capital Ltd',
#   'created_at': '2024-01-10T05:38:00.000000Z',
#   'updated_at': '2024-01-10T05:48:58.000000Z',
#   'price': '360.9',
#   'last_closing_date': None,
#   'type': 'Ordinary',
#   'url': None,
#   'status': '<span style="color: #E81E62;text-align: center" class="no-line-break">Closed</span>',
#   'stockinfo': []},
#  {'id': 3141,
#   'symbol': 'SARBOTTAM(Local)',
#   'company_name': 'Sarbottam Cement Limited',
#   'units': '930000',
#   'opening_date': '2024-01-10',
#   'closing_date': '2024-01-24',
#   'issue_manager': 'Global IME Capital Ltd',
#   'created_at': '2024-01-10T05:47:43.000000Z',
#   'updated_at': '2024-01-10T05:47:43.000000Z',
#   'price': '360.9',
#   'last_closing_date': '2024-02-08',
#   'type': 'Ordinary',
# ...

# %%
for i in data['ipo']:
    print(i)
# Out:
# {'id': 3140, 'symbol': 'SARBOTTAM(Nepalese Working Abroad)', 'company_name': 'Sarbottam Cement Limited', 'units': '267000', 'opening_date': '2024-01-10', 'closing_date': '2024-01-24', 'issue_manager': 'Global IME Capital Ltd', 'created_at': '2024-01-10T05:38:00.000000Z', 'updated_at': '2024-01-10T05:48:58.000000Z', 'price': '360.9', 'last_closing_date': None, 'type': 'Ordinary', 'url': None, 'status': '<span style="color: #E81E62;text-align: center" class="no-line-break">Closed</span>', 'stockinfo': []}
# ...

# %%
for i in data['ipo']:
    # print(i)
    if i['opening_date']=='2023-10-10':
        print("Ipo Opening")
        print(i['symbol'])
    if i['closing_date'] =='2023-10-13':
        print("Ipo closing")
        print(i['symbol'])
# Out:
# Ipo Opening
# Chirkhwa (Public)
# Ipo closing
# Chirkhwa (Public)

# %%
import requests
token = "bot6488739598:AAH_K5tJ1GgL9_6lKzZjhQaUdy8KQVVDNC0"
params = {
        "chat_id": "@hellorajan22",
        "text": "Good Morning"
    }

r = requests.post(
    f'https://api.telegram.org/{token}/sendMessage', params=params
)
print(r.json())
# Out:
# {'ok': True, 'result': {'message_id': 5, 'sender_chat': {'id': -1002137830736, 'title': 'broadway', 'username': 'hellorajan22', 'type': 'channel'}, 'chat': {'id': -1002137830736, 'title': 'broadway', 'username': 'hellorajan22', 'type': 'channel'}, 'date': 1707183636, 'text': 'Good Morning'}}
